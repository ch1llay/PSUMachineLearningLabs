# %% [markdown]
# импортируем пакеты

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# импортируем датасет

# %%
dataset_path = "../datasets/gtzan/features_30_sec.csv"
data = pd.read_csv(dataset_path, delimiter=',')

data[["label", "tempo"]]
# Out:
#      label       tempo
# 0    blues  123.046875
# 1    blues   67.999589
# 2    blues  161.499023
# 3    blues   63.024009
# 4    blues  135.999178
# ..     ...         ...
# 995   rock  103.359375
# 996   rock  117.453835
# 997   rock  129.199219
# 998   rock   73.828125
# 999   rock  123.046875
#
# [1000 rows x 2 columns]

# %% [markdown]
# фильтрация

# %%
filter_data = data[data['chroma_stft_mean'] > 0.350088]
filter_data
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0    blues.00000.wav  661794          0.350088         0.088757  0.130228
# 2    blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3    blues.00003.wav  661794          0.404785         0.093999  0.141093
# 8    blues.00008.wav  661794          0.408879         0.086512  0.142416
# 11   blues.00011.wav  661794          0.367152         0.102329  0.065741
# ..               ...     ...               ...              ...       ...
# 995   rock.00095.wav  661794          0.352063         0.080487  0.079486
# 996   rock.00096.wav  661794          0.398687         0.075086  0.076458
# 997   rock.00097.wav  661794          0.432142         0.075268  0.081651
# 998   rock.00098.wav  661794          0.362485         0.091506  0.083860
# 999   rock.00099.wav  661794          0.358401         0.085884  0.054454
#
#       rms_var  spectral_centroid_mean  spectral_centroid_var  \
# ...

# %% [markdown]
# выводим первый столбец

# %%
filter_data.iloc[:, 0]
# Out:
# 0      blues.00000.wav
# 2      blues.00002.wav
# 3      blues.00003.wav
# 8      blues.00008.wav
# 11     blues.00011.wav
#             ...
# 995     rock.00095.wav
# 996     rock.00096.wav
# 997     rock.00097.wav
# 998     rock.00098.wav
# 999     rock.00099.wav
# Name: filename, Length: 650, dtype: object

# %% [markdown]
# выводим третий столбец

# %%
filter_data.iloc[:, 2]
# Out:
# 0      0.350088
# 2      0.363637
# 3      0.404785
# 8      0.408879
# 11     0.367152
#          ...
# 995    0.352063
# 996    0.398687
# 997    0.432142
# 998    0.362485
# 999    0.358401
# Name: chroma_stft_mean, Length: 650, dtype: float64

# %% [markdown]
# выводим первый и третий столбцы вместе

# %%
filter_data.iloc[:, [0, 2]]
# Out:
#             filename  chroma_stft_mean
# 0    blues.00000.wav          0.350088
# 2    blues.00002.wav          0.363637
# 3    blues.00003.wav          0.404785
# 8    blues.00008.wav          0.408879
# 11   blues.00011.wav          0.367152
# ..               ...               ...
# 995   rock.00095.wav          0.352063
# 996   rock.00096.wav          0.398687
# 997   rock.00097.wav          0.432142
# 998   rock.00098.wav          0.362485
# 999   rock.00099.wav          0.358401
#
# [650 rows x 2 columns]

# %% [markdown]
# выводим первые 10 строк

# %%
выводим случайные 23 строки

# %%
data.sample(23)
# Out:
#                 filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 231    country.00031.wav  661794          0.313399         0.081925  0.100855
# 892     reggae.00092.wav  661504          0.398761         0.090296  0.092221
# 850     reggae.00050.wav  661504          0.460017         0.083592  0.131030
# 325      disco.00025.wav  661794          0.358008         0.093773  0.107915
# 121  classical.00021.wav  661794          0.266747         0.083575  0.045480
# 134  classical.00034.wav  661794          0.273979         0.090914  0.038912
# 324      disco.00024.wav  661794          0.372727         0.081019  0.142980
# 748        pop.00048.wav  661504          0.465091         0.084325  0.156646
# 212    country.00012.wav  661794          0.296564         0.090031  0.126964
# 429     hiphop.00029.wav  669240          0.439458         0.092914  0.166723
# 289    country.00089.wav  661794          0.322182         0.090080  0.104694
# ...

# %% [markdown]
# выводим статистику по числовым показателям

# %%
data.describe()
# Out:
#               length  chroma_stft_mean  chroma_stft_var     rms_mean  \
# count    1000.000000       1000.000000      1000.000000  1000.000000
# mean   662030.846000          0.378682         0.086340     0.130930
# std      1784.073992          0.081705         0.007735     0.065683
# min    660000.000000          0.171939         0.044555     0.005276
# 25%    661504.000000          0.319562         0.082298     0.086657
# 50%    661794.000000          0.383148         0.086615     0.122443
# 75%    661794.000000          0.435942         0.091256     0.175682
# max    675808.000000          0.663685         0.108111     0.397973
#
#            rms_var  spectral_centroid_mean  spectral_centroid_var  \
# count  1000.000000             1000.000000           1.000000e+03
# mean      0.003051             2201.780898           4.696916e+05
# std       0.003634              715.960600           4.008995e+05
# min       0.000004              570.040355           7.911251e+03
# ...

# %% [markdown]
# группируем по жанру (столбец label)

# %%
group = data.groupby(by=['label'])

# %% [markdown]
# выведем количество строк по каждому жанру

# %%
group.tempo.describe()
